# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://stats.nba.com/teams/traditional/?sort=W_PCT&dir=-1&Season=2016-17&SeasonType=Regular%20Season"

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')

# %%
soup.find_all("div", class_="nba-stat-table__overflow")
# Out:
# []

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" ng-app="stats" ng-strict-di="" stats-build-date="2018-04-16 10:08 AM" stats-version="4.8.4" xmlns:ng="http://angularjs.org">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    NBA.com/Stats  | Teams Traditional
#   </title>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Home of NBA Advanced Stats - Official NBA Statistics and Advanced Analytics." name="description"/>
#   <link href="https://stats.nba.com/teams/traditional/?Season=2016-17&amp;SeasonType=Regular%20Season&amp;dir=-1&amp;sort=W_PCT" rel="canonical"/>
#   <base href="/teams/traditional/"/>
#   <meta content="https://stats.nba.com/teams/traditional/?Season=2016-17&amp;SeasonType=Regular%20Season&amp;dir=-1&amp;sort=W_PCT" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="NBA Stats" property="og:site_name"/>
# ...

# %%
pd.read_html(table)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-79e9499810fc> in <module>()
# ----> 1 pd.read_html(table)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na)
#     913                   thousands=thousands, attrs=attrs, encoding=encoding,
#     914                   decimal=decimal, converters=converters, na_values=na_values,
# --> 915                   keep_default_na=keep_default_na)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, **kwargs)
#     747             break
#     748     else:
# --> 749         raise_with_traceback(retained)
#     750
#     751     ret = []
#
# ...
